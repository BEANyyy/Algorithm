# %% [markdown]
# csv 파일 읽어오기

# %%
import pandas as pd
df = pd.read_csv('webLog.csv')
df
# Out:
#                IP                   Time                        URL  Staus
# 0      10.131.2.1  [30/Nov/2017:08:46:59             GET / HTTP/1.0    302
# 1      10.128.2.1  [29/Nov/2017:16:45:00             GET / HTTP/1.1    302
# 2      10.128.2.1  [29/Nov/2017:17:00:05             GET / HTTP/1.1    302
# 3      10.128.2.1  [29/Nov/2017:18:15:39             GET / HTTP/1.1    200
# 4      10.128.2.1  [29/Nov/2017:22:21:16             GET / HTTP/1.1    302
# ...           ...                    ...                        ...    ...
# 15784  10.128.2.1  [12/Nov/2017:12:58:39  POST /update.php HTTP/1.1    200
# 15785  10.129.2.1  [12/Nov/2017:12:43:54  POST /update.php HTTP/1.1    200
# 15786  10.129.2.1  [12/Nov/2017:12:43:54  POST /update.php HTTP/1.1    200
# 15787  10.131.0.1  [30/Nov/2017:15:57:41  POST /update.php HTTP/1.1    200
# 15788  10.131.0.1  [30/Nov/2017:17:16:26  POST /update.php HTTP/1.1    200
#
# [15789 rows x 4 columns]

# %% [markdown]
# 한 열씩 정렬

# %%
#시간 기준
df_sort_time = df.sort_values(by=df.columns[1], ascending=True)
print(df_sort_time)

#ip 기준
df_sort_ip = df.sort_values(by=df.columns[0], ascending=True)
print(df_sort_ip)
# Out:
#                IP                   Time  \
# 240    10.129.2.1  [01/Dec/2017:00:06:02
# 13984  10.131.2.1  [01/Dec/2017:00:06:02
# 376    10.130.2.1  [01/Dec/2017:00:40:11
# 10875  10.128.2.1  [01/Dec/2017:00:40:11
# 15679  10.131.0.1  [01/Dec/2017:00:41:00
# ...           ...                    ...
# 5490   10.129.2.1  [30/Nov/2017:21:01:34
# 10874  10.128.2.1  [30/Nov/2017:21:29:16
# 767    10.131.2.1  [30/Nov/2017:21:29:16
# 239    10.129.2.1  [30/Nov/2017:21:48:21
# 13983  10.131.2.1  [30/Nov/2017:21:48:22
#
#                                                      URL  Staus
# 240                                       GET / HTTP/1.1    302
# 13984                            GET /login.php HTTP/1.1    200
# 376                                       GET / HTTP/1.1    302
# 10875                            GET /login.php HTTP/1.1    200
# 15679                         POST /process.php HTTP/1.1    302
# ...                                                  ...    ...
# ...
